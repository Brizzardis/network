# %%
from keras.datasets import fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 7s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 2s 0us/step

# %%
import numpy as np
from keras.datasets import fashion_mnist as mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# Normalize the images.
train_images = (train_images / 255) - 0.5
test_images = (test_images / 255) - 0.5

# Flatten the images.
train_images = train_images.reshape((-1, 784))
test_images = test_images.reshape((-1, 784))

# Build the model.
model = Sequential([
  Dense(128, activation='relu', input_shape=(784,)),
  Dense(128, activation='relu'),
  Dense(128, activation='relu'),
  Dense(10, activation='softmax'),
])

adam = keras.optimizers.Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, amsgrad=False)
# Compile the model.
model.compile(
  optimizer=adam,
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)

# Train the model.
model.fit(
  train_images,
  to_categorical(train_labels),
  epochs=100,
  batch_size=32,
)

# Evaluate the model.
model.evaluate(
  test_images,
  to_categorical(test_labels)
)

# Save the model to disk.
# model.save_weights('model.h5')

# Load the model from disk later using:
# model.load_weights('model.h5')

# Predict on the first 5 test images.
predictions = model.predict(test_images[:5])

# Print our model's predictions.
print(np.argmax(predictions, axis=1)) 

# Check our predictions against the ground truths.
print(test_labels[:5])
# Out:
# Epoch 1/100
# 60000/60000 [==============================] - 4s 71us/step - loss: 0.4980 - accuracy: 0.8202
# Epoch 2/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.3676 - accuracy: 0.8650
# Epoch 3/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.3301 - accuracy: 0.8788
# Epoch 4/100
# 60000/60000 [==============================] - 4s 71us/step - loss: 0.3058 - accuracy: 0.8853
# Epoch 5/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.2891 - accuracy: 0.8922
# Epoch 6/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.2728 - accuracy: 0.8990
# Epoch 7/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.2591 - accuracy: 0.9024
# Epoch 8/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.2469 - accuracy: 0.9078
# Epoch 9/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.2359 - accuracy: 0.9123
# Epoch 10/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.2232 - accuracy: 0.9160
# Epoch 11/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.2153 - accuracy: 0.9190
# Epoch 12/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.2057 - accuracy: 0.9223
# Epoch 13/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.1972 - accuracy: 0.9245
# Epoch 14/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.1907 - accuracy: 0.9272
# Epoch 15/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.1803 - accuracy: 0.9333
# Epoch 16/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.1754 - accuracy: 0.9341
# Epoch 17/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.1669 - accuracy: 0.9378
# Epoch 18/100
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.1613 - accuracy: 0.9397
# Epoch 19/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.1516 - accuracy: 0.9418
# Epoch 20/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.1477 - accuracy: 0.9448
# Epoch 21/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.1422 - accuracy: 0.9450
# Epoch 22/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.1342 - accuracy: 0.9499
# Epoch 23/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.1290 - accuracy: 0.9513
# Epoch 24/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.1227 - accuracy: 0.9535
# Epoch 25/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.1191 - accuracy: 0.9541
# Epoch 26/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.1140 - accuracy: 0.9566
# Epoch 27/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.1096 - accuracy: 0.9581
# Epoch 28/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.1066 - accuracy: 0.9590
# Epoch 29/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.1025 - accuracy: 0.9616
# Epoch 30/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0996 - accuracy: 0.9620
# Epoch 31/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0927 - accuracy: 0.9644
# Epoch 32/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0906 - accuracy: 0.9653
# Epoch 33/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0874 - accuracy: 0.9661
# Epoch 34/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0841 - accuracy: 0.9688
# Epoch 35/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0790 - accuracy: 0.9704
# Epoch 36/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0800 - accuracy: 0.9703
# Epoch 37/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0739 - accuracy: 0.9718
# Epoch 38/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0720 - accuracy: 0.9727
# Epoch 39/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0710 - accuracy: 0.9733
# Epoch 40/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0716 - accuracy: 0.9731
# Epoch 41/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0661 - accuracy: 0.9757
# Epoch 42/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0661 - accuracy: 0.9751
# Epoch 43/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0635 - accuracy: 0.9761
# Epoch 44/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0630 - accuracy: 0.9767
# Epoch 45/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0584 - accuracy: 0.9782
# Epoch 46/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0593 - accuracy: 0.9774
# Epoch 47/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0578 - accuracy: 0.9785
# Epoch 48/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0547 - accuracy: 0.9798
# Epoch 49/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0553 - accuracy: 0.9792
# Epoch 50/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0519 - accuracy: 0.9811
# Epoch 51/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0497 - accuracy: 0.9815
# Epoch 52/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0507 - accuracy: 0.9823
# Epoch 53/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0521 - accuracy: 0.9807
# Epoch 54/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0458 - accuracy: 0.9833
# Epoch 55/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0475 - accuracy: 0.9818
# Epoch 56/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0470 - accuracy: 0.9829
# Epoch 57/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0462 - accuracy: 0.9836
# Epoch 58/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0442 - accuracy: 0.9833
# Epoch 59/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0453 - accuracy: 0.9836
# Epoch 60/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0468 - accuracy: 0.9830
# Epoch 61/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0400 - accuracy: 0.9853
# Epoch 62/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0435 - accuracy: 0.9845
# Epoch 63/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0388 - accuracy: 0.9857
# Epoch 64/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0461 - accuracy: 0.9831
# Epoch 65/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0393 - accuracy: 0.9855
# Epoch 66/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0399 - accuracy: 0.9859
# Epoch 67/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0365 - accuracy: 0.9873
# Epoch 68/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0349 - accuracy: 0.9872
# Epoch 69/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0434 - accuracy: 0.9846
# Epoch 70/100
# 60000/60000 [==============================] - 4s 71us/step - loss: 0.0319 - accuracy: 0.9884
# Epoch 71/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0408 - accuracy: 0.9855
# Epoch 72/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0362 - accuracy: 0.9871
# Epoch 73/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0354 - accuracy: 0.9871
# Epoch 74/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0374 - accuracy: 0.9867
# Epoch 75/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0363 - accuracy: 0.9869
# Epoch 76/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0353 - accuracy: 0.9876
# Epoch 77/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0350 - accuracy: 0.9880
# Epoch 78/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0350 - accuracy: 0.9874
# Epoch 79/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0313 - accuracy: 0.9892
# Epoch 80/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0313 - accuracy: 0.9884
# Epoch 81/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0385 - accuracy: 0.9874
# Epoch 82/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0308 - accuracy: 0.9889
# Epoch 83/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0320 - accuracy: 0.9888
# Epoch 84/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0312 - accuracy: 0.9894
# Epoch 85/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0308 - accuracy: 0.9888
# Epoch 86/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0304 - accuracy: 0.9890
# Epoch 87/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0315 - accuracy: 0.9893
# Epoch 88/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0328 - accuracy: 0.9887
# Epoch 89/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0321 - accuracy: 0.9893
# Epoch 90/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0287 - accuracy: 0.9899
# Epoch 91/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0287 - accuracy: 0.9904
# Epoch 92/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0292 - accuracy: 0.9895
# Epoch 93/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0287 - accuracy: 0.9900
# Epoch 94/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0297 - accuracy: 0.9897
# Epoch 95/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0282 - accuracy: 0.9906
# Epoch 96/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0311 - accuracy: 0.9892
# Epoch 97/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0269 - accuracy: 0.9909
# Epoch 98/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0319 - accuracy: 0.9898
# Epoch 99/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0286 - accuracy: 0.9905
# Epoch 100/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0256 - accuracy: 0.9911
# 10000/10000 [==============================] - 0s 25us/step
# [9 2 1 1 6]
# [9 2 1 1 6]

# %% [raw]
# При количестве эпох равном 100 точность = 0.9911
# Уменьшение learning_rate  повысило точность
